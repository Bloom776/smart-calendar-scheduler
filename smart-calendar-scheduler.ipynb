# %%
# !pip install openai google-api-python-client google-auth-httplib2 google-auth-oauthlib langchain
# Out:
# Collecting openai
#   Using cached openai-1.86.0-py3-none-any.whl.metadata (25 kB)
# Collecting google-api-python-client
#   Using cached google_api_python_client-2.172.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting google-auth-httplib2
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth-oauthlib
#   Using cached google_auth_oauthlib-1.2.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting langchain
#   Downloading langchain-0.3.25-py3-none-any.whl.metadata (7.8 kB)
# Collecting anyio<5,>=3.5.0 (from openai)
#   Downloading anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.10.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Downloading pydantic-2.11.5-py3-none-any.whl.metadata (67 kB)
# Collecting sniffio (from openai)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting typing-extensions<5,>=4.11 (from openai)
#   Downloading typing_extensions-4.14.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->openai)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting certifi (from httpx<1,>=0.23.0->openai)
#   Downloading certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3,>=1.9.0->openai)
#   Downloading pydantic_core-2.33.2-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3,>=1.9.0->openai)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting httplib2<1.0.0,>=0.19.0 (from google-api-python-client)
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 (from google-api-python-client)
#   Downloading google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 (from google-api-python-client)
#   Downloading google_api_core-2.25.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client)
#   Downloading uritemplate-4.2.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Using cached googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Downloading protobuf-6.31.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Using cached proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting requests<3.0.0,>=2.18.0 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 (from httplib2<1.0.0,>=0.19.0->google-api-python-client)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Downloading charset_normalizer-3.4.2-cp313-cp313-win_amd64.whl.metadata (36 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting langchain-core<1.0.0,>=0.3.58 (from langchain)
#   Downloading langchain_core-0.3.65-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-text-splitters<1.0.0,>=0.3.8 (from langchain)
#   Using cached langchain_text_splitters-0.3.8-py3-none-any.whl.metadata (1.9 kB)
# Collecting langsmith<0.4,>=0.1.17 (from langchain)
#   Downloading langsmith-0.3.45-py3-none-any.whl.metadata (15 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading sqlalchemy-2.0.41-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting PyYAML>=5.3 (from langchain)
#   Downloading PyYAML-6.0.2-cp313-cp313-win_amd64.whl.metadata (2.1 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<1.0.0,>=0.3.58->langchain)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<1.0.0,>=0.3.58->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting packaging<25,>=23.2 (from langchain-core<1.0.0,>=0.3.58->langchain)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.4,>=0.1.17->langchain)
#   Downloading orjson-3.10.18-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt<2.0.0,>=1.0.0 (from langsmith<0.4,>=0.1.17->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zstandard<0.24.0,>=0.23.0 (from langsmith<0.4,>=0.1.17->langchain)
#   Downloading zstandard-0.23.0-cp313-cp313-win_amd64.whl.metadata (3.0 kB)
# Collecting greenlet>=1 (from SQLAlchemy<3,>=1.4->langchain)
#   Downloading greenlet-3.2.3-cp313-cp313-win_amd64.whl.metadata (4.2 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: colorama in c:\users\user\admin agent\.venv\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Using cached openai-1.86.0-py3-none-any.whl (730 kB)
# Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jiter-0.10.0-cp313-cp313-win_amd64.whl (205 kB)
# Downloading pydantic-2.11.5-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp313-cp313-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 636.7 kB/s eta 0:00:03
#    ---------------- ----------------------- 0.8/2.0 MB 805.6 kB/s eta 0:00:02
#    --------------------- ------------------ 1.0/2.0 MB 921.0 kB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 983.7 kB/s eta 0:00:01
#    -------------------------------- ------- 1.6/2.0 MB 1.0 MB/s eta 0:00:01
#    ------------------------------------- -- 1.8/2.0 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.1 MB/s eta 0:00:00
# Downloading typing_extensions-4.14.0-py3-none-any.whl (43 kB)
# Using cached google_api_python_client-2.172.0-py3-none-any.whl (13.6 MB)
# Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading google_api_core-2.25.0-py3-none-any.whl (160 kB)
# Downloading google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Using cached httplib2-0.22.0-py3-none-any.whl (96 kB)
# Using cached proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Downloading protobuf-6.31.1-cp310-abi3-win_amd64.whl (435 kB)
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp313-cp313-win_amd64.whl (105 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Using cached google_auth_oauthlib-1.2.2-py3-none-any.whl (19 kB)
# Downloading langchain-0.3.25-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 1.7 MB/s eta 0:00:00
# Downloading langchain_core-0.3.65-py3-none-any.whl (438 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langchain_text_splitters-0.3.8-py3-none-any.whl (32 kB)
# Downloading langsmith-0.3.45-py3-none-any.whl (363 kB)
# Downloading orjson-3.10.18-cp313-cp313-win_amd64.whl (134 kB)
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading sqlalchemy-2.0.41-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.1 MB 1.7 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 2.1 MB/s eta 0:00:00
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Downloading zstandard-0.23.0-cp313-cp313-win_amd64.whl (495 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
# Downloading greenlet-3.2.3-cp313-cp313-win_amd64.whl (297 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading PyYAML-6.0.2-cp313-cp313-win_amd64.whl (156 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Installing collected packages: zstandard, urllib3, uritemplate, typing-extensions, tqdm, tenacity, sniffio, PyYAML, pyparsing, pyasn1, protobuf, packaging, orjson, oauthlib, jsonpointer, jiter, idna, h11, greenlet, distro, charset_normalizer, certifi, cachetools, annotated-types, typing-inspection, SQLAlchemy, rsa, requests, pydantic-core, pyasn1-modules, proto-plus, jsonpatch, httplib2, httpcore, googleapis-common-protos, anyio, requests-toolbelt, requests-oauthlib, pydantic, httpx, google-auth, openai, langsmith, google-auth-oauthlib, google-auth-httplib2, google-api-core, langchain-core, google-api-python-client, langchain-text-splitters, langchain
#
#    ----------------------------------------  0/50 [zstandard]
#     ---------------------------------------  1/50 [urllib3]
#     ---------------------------------------  1/50 [urllib3]
#     ---------------------------------------  1/50 [urllib3]
#     ---------------------------------------  1/50 [urllib3]
#     ---------------------------------------  1/50 [urllib3]
#     ---------------------------------------  1/50 [urllib3]
#     ---------------------------------------  1/50 [urllib3]
#     ---------------------------------------  1/50 [urllib3]
#     ---------------------------------------  1/50 [urllib3]
#    - --------------------------------------  2/50 [uritemplate]
#    -- -------------------------------------  3/50 [typing-extensions]
#    --- ------------------------------------  4/50 [tqdm]
#    --- ------------------------------------  4/50 [tqdm]
#    --- ------------------------------------  4/50 [tqdm]
#    --- ------------------------------------  4/50 [tqdm]
#    --- ------------------------------------  4/50 [tqdm]
#    --- ------------------------------------  4/50 [tqdm]
#    --- ------------------------------------  4/50 [tqdm]
#    --- ------------------------------------  4/50 [tqdm]
#    --- ------------------------------------  4/50 [tqdm]
#    ---- -----------------------------------  5/50 [tenacity]
#    ---- -----------------------------------  5/50 [tenacity]
#    ---- -----------------------------------  5/50 [tenacity]
#    ---- -----------------------------------  6/50 [sniffio]
#    ----- ----------------------------------  7/50 [PyYAML]
#    ----- ----------------------------------  7/50 [PyYAML]
#    ----- ----------------------------------  7/50 [PyYAML]
#    ----- ----------------------------------  7/50 [PyYAML]
#    ----- ----------------------------------  7/50 [PyYAML]
#    ------ ---------------------------------  8/50 [pyparsing]
#    ------ ---------------------------------  8/50 [pyparsing]
#    ------ ---------------------------------  8/50 [pyparsing]
#    ------- --------------------------------  9/50 [pyasn1]
#    ------- --------------------------------  9/50 [pyasn1]
#    ------- --------------------------------  9/50 [pyasn1]
#    ------- --------------------------------  9/50 [pyasn1]
#    ------- --------------------------------  9/50 [pyasn1]
#    ------- --------------------------------  9/50 [pyasn1]
#    ------- --------------------------------  9/50 [pyasn1]
#    -------- ------------------------------- 10/50 [protobuf]
#    -------- ------------------------------- 10/50 [protobuf]
#    -------- ------------------------------- 10/50 [protobuf]
#    -------- ------------------------------- 10/50 [protobuf]
#    -------- ------------------------------- 10/50 [protobuf]
#    -------- ------------------------------- 10/50 [protobuf]
#    -------- ------------------------------- 10/50 [protobuf]
#    -------- ------------------------------- 10/50 [protobuf]
#    -------- ------------------------------- 10/50 [protobuf]
#    -------- ------------------------------- 10/50 [protobuf]
#    -------- ------------------------------- 10/50 [protobuf]
#    -------- ------------------------------- 10/50 [protobuf]
#    -------- ------------------------------- 10/50 [protobuf]
#    -------- ------------------------------- 10/50 [protobuf]
#    -------- ------------------------------- 10/50 [protobuf]
#    -------- ------------------------------- 10/50 [protobuf]
#   Attempting uninstall: packaging
#    -------- ------------------------------- 10/50 [protobuf]
#     Found existing installation: packaging 25.0
#    -------- ------------------------------- 10/50 [protobuf]
#     Uninstalling packaging-25.0:
#    -------- ------------------------------- 10/50 [protobuf]
#       Successfully uninstalled packaging-25.0
#    -------- ------------------------------- 10/50 [protobuf]
#    -------- ------------------------------- 11/50 [packaging]
#    -------- ------------------------------- 11/50 [packaging]
#    -------- ------------------------------- 11/50 [packaging]
#    -------- ------------------------------- 11/50 [packaging]
#    ---------- ----------------------------- 13/50 [oauthlib]
#    ---------- ----------------------------- 13/50 [oauthlib]
#    ---------- ----------------------------- 13/50 [oauthlib]
#    ---------- ----------------------------- 13/50 [oauthlib]
#    ---------- ----------------------------- 13/50 [oauthlib]
#    ---------- ----------------------------- 13/50 [oauthlib]
#    ---------- ----------------------------- 13/50 [oauthlib]
#    ---------- ----------------------------- 13/50 [oauthlib]
#    ---------- ----------------------------- 13/50 [oauthlib]
#    ---------- ----------------------------- 13/50 [oauthlib]
#    ---------- ----------------------------- 13/50 [oauthlib]
#    ---------- ----------------------------- 13/50 [oauthlib]
#    ---------- ----------------------------- 13/50 [oauthlib]
#    ---------- ----------------------------- 13/50 [oauthlib]
#    ---------- ----------------------------- 13/50 [oauthlib]
#    ----------- ---------------------------- 14/50 [jsonpointer]
#    ------------ --------------------------- 16/50 [idna]
#    ------------ --------------------------- 16/50 [idna]
#    ------------- -------------------------- 17/50 [h11]
#    ------------- -------------------------- 17/50 [h11]
#    ------------- -------------------------- 17/50 [h11]
#    -------------- ------------------------- 18/50 [greenlet]
#    -------------- ------------------------- 18/50 [greenlet]
#    -------------- ------------------------- 18/50 [greenlet]
#    -------------- ------------------------- 18/50 [greenlet]
#    -------------- ------------------------- 18/50 [greenlet]
#    -------------- ------------------------- 18/50 [greenlet]
#    --------------- ------------------------ 19/50 [distro]
#    --------------- ------------------------ 19/50 [distro]
#    ---------------- ----------------------- 20/50 [charset_normalizer]
#    ---------------- ----------------------- 20/50 [charset_normalizer]
#    ---------------- ----------------------- 20/50 [charset_normalizer]
#    ---------------- ----------------------- 20/50 [charset_normalizer]
#    ---------------- ----------------------- 20/50 [charset_normalizer]
#    ---------------- ----------------------- 21/50 [certifi]
#    ----------------- ---------------------- 22/50 [cachetools]
#    ------------------ --------------------- 23/50 [annotated-types]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 25/50 [SQLAlchemy]
#    -------------------- ------------------- 26/50 [rsa]
#    -------------------- ------------------- 26/50 [rsa]
#    -------------------- ------------------- 26/50 [rsa]
#    -------------------- ------------------- 26/50 [rsa]
#    -------------------- ------------------- 26/50 [rsa]
#    -------------------- ------------------- 26/50 [rsa]
#    -------------------- ------------------- 26/50 [rsa]
#    -------------------- ------------------- 26/50 [rsa]
#    -------------------- ------------------- 26/50 [rsa]
#    -------------------- ------------------- 26/50 [rsa]
#    -------------------- ------------------- 26/50 [rsa]
#    -------------------- ------------------- 26/50 [rsa]
#    --------------------- ------------------ 27/50 [requests]
#    --------------------- ------------------ 27/50 [requests]
#    --------------------- ------------------ 27/50 [requests]
#    --------------------- ------------------ 27/50 [requests]
#    ---------------------- ----------------- 28/50 [pydantic-core]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ----------------------- ---------------- 29/50 [pyasn1-modules]
#    ------------------------ --------------- 30/50 [proto-plus]
#    ------------------------ --------------- 30/50 [proto-plus]
#    ------------------------ --------------- 30/50 [proto-plus]
#    ------------------------ --------------- 30/50 [proto-plus]
#    ------------------------ --------------- 30/50 [proto-plus]
#    ------------------------ --------------- 31/50 [jsonpatch]
#    ------------------------- -------------- 32/50 [httplib2]
#    -------------------------- ------------- 33/50 [httpcore]
#    -------------------------- ------------- 33/50 [httpcore]
#    -------------------------- ------------- 33/50 [httpcore]
#    -------------------------- ------------- 33/50 [httpcore]
#    -------------------------- ------------- 33/50 [httpcore]
#    -------------------------- ------------- 33/50 [httpcore]
#    -------------------------- ------------- 33/50 [httpcore]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    --------------------------- ------------ 34/50 [googleapis-common-protos]
#    ---------------------------- ----------- 35/50 [anyio]
#    ---------------------------- ----------- 35/50 [anyio]
#    ---------------------------- ----------- 35/50 [anyio]
#    ---------------------------- ----------- 35/50 [anyio]
#    ---------------------------- ----------- 35/50 [anyio]
#    ---------------------------- ----------- 35/50 [anyio]
#    ---------------------------- ----------- 35/50 [anyio]
#    ---------------------------- ----------- 35/50 [anyio]
#    ---------------------------- ----------- 35/50 [anyio]
#    ---------------------------- ----------- 36/50 [requests-toolbelt]
#    ---------------------------- ----------- 36/50 [requests-toolbelt]
#    ---------------------------- ----------- 36/50 [requests-toolbelt]
#    ---------------------------- ----------- 36/50 [requests-toolbelt]
#    ---------------------------- ----------- 36/50 [requests-toolbelt]
#    ---------------------------- ----------- 36/50 [requests-toolbelt]
#    ----------------------------- ---------- 37/50 [requests-oauthlib]
#    ----------------------------- ---------- 37/50 [requests-oauthlib]
#    ----------------------------- ---------- 37/50 [requests-oauthlib]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------ --------- 38/50 [pydantic]
#    ------------------------------- -------- 39/50 [httpx]
#    ------------------------------- -------- 39/50 [httpx]
#    ------------------------------- -------- 39/50 [httpx]
#    ------------------------------- -------- 39/50 [httpx]
#    ------------------------------- -------- 39/50 [httpx]
#    ------------------------------- -------- 39/50 [httpx]
#    ------------------------------- -------- 39/50 [httpx]
#    ------------------------------- -------- 39/50 [httpx]
#    -------------------------------- ------- 40/50 [google-auth]
#    -------------------------------- ------- 40/50 [google-auth]
#    -------------------------------- ------- 40/50 [google-auth]
#    -------------------------------- ------- 40/50 [google-auth]
#    -------------------------------- ------- 40/50 [google-auth]
#    -------------------------------- ------- 40/50 [google-auth]
#    -------------------------------- ------- 40/50 [google-auth]
#    -------------------------------- ------- 40/50 [google-auth]
#    -------------------------------- ------- 40/50 [google-auth]
#    -------------------------------- ------- 40/50 [google-auth]
#    -------------------------------- ------- 40/50 [google-auth]
#    -------------------------------- ------- 40/50 [google-auth]
#    -------------------------------- ------- 40/50 [google-auth]
#    -------------------------------- ------- 40/50 [google-auth]
#    -------------------------------- ------- 40/50 [google-auth]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    -------------------------------- ------- 41/50 [openai]
#    --------------------------------- ------ 42/50 [langsmith]
#    --------------------------------- ------ 42/50 [langsmith]
#    --------------------------------- ------ 42/50 [langsmith]
#    --------------------------------- ------ 42/50 [langsmith]
#    --------------------------------- ------ 42/50 [langsmith]
#    --------------------------------- ------ 42/50 [langsmith]
#    --------------------------------- ------ 42/50 [langsmith]
#    --------------------------------- ------ 42/50 [langsmith]
#    --------------------------------- ------ 42/50 [langsmith]
#    --------------------------------- ------ 42/50 [langsmith]
#    --------------------------------- ------ 42/50 [langsmith]
#    --------------------------------- ------ 42/50 [langsmith]
#    --------------------------------- ------ 42/50 [langsmith]
#    ---------------------------------- ----- 43/50 [google-auth-oauthlib]
#    ---------------------------------- ----- 43/50 [google-auth-oauthlib]
#    ---------------------------------- ----- 43/50 [google-auth-oauthlib]
#    ------------------------------------ --- 45/50 [google-api-core]
#    ------------------------------------ --- 45/50 [google-api-core]
#    ------------------------------------ --- 45/50 [google-api-core]
#    ------------------------------------ --- 45/50 [google-api-core]
#    ------------------------------------ --- 45/50 [google-api-core]
#    ------------------------------------ --- 45/50 [google-api-core]
#    ------------------------------------ --- 45/50 [google-api-core]
#    ------------------------------------ --- 45/50 [google-api-core]
#    ------------------------------------ --- 45/50 [google-api-core]
#    ------------------------------------ --- 45/50 [google-api-core]
#    ------------------------------------ --- 45/50 [google-api-core]
#    ------------------------------------ --- 45/50 [google-api-core]
#    ------------------------------------ --- 45/50 [google-api-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------ --- 46/50 [langchain-core]
#    ------------------------------------- -- 47/50 [google-api-python-client]
#    ------------------------------------- -- 47/50 [google-api-python-client]
#    ------------------------------------- -- 47/50 [google-api-python-client]
#    ------------------------------------- -- 47/50 [google-api-python-client]
#    ------------------------------------- -- 47/50 [google-api-python-client]
#    ------------------------------------- -- 47/50 [google-api-python-client]
#    ------------------------------------- -- 47/50 [google-api-python-client]
#    ------------------------------------- -- 47/50 [google-api-python-client]
#    ------------------------------------- -- 47/50 [google-api-python-client]
#    ------------------------------------- -- 47/50 [google-api-python-client]
#    ------------------------------------- -- 47/50 [google-api-python-client]
#    ------------------------------------- -- 47/50 [google-api-python-client]
#    ------------------------------------- -- 47/50 [google-api-python-client]
#    ------------------------------------- -- 47/50 [google-api-python-client]
#    ------------------------------------- -- 47/50 [google-api-python-client]
#    ------------------------------------- -- 47/50 [google-api-python-client]
#    ------------------------------------- -- 47/50 [google-api-python-client]
#    -------------------------------------- - 48/50 [langchain-text-splitters]
#    -------------------------------------- - 48/50 [langchain-text-splitters]
#    -------------------------------------- - 48/50 [langchain-text-splitters]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------  49/50 [langchain]
#    ---------------------------------------- 50/50 [langchain]
#
# Successfully installed PyYAML-6.0.2 SQLAlchemy-2.0.41 annotated-types-0.7.0 anyio-4.9.0 cachetools-5.5.2 certifi-2025.4.26 charset_normalizer-3.4.2 distro-1.9.0 google-api-core-2.25.0 google-api-python-client-2.172.0 google-auth-2.40.3 google-auth-httplib2-0.2.0 google-auth-oauthlib-1.2.2 googleapis-common-protos-1.70.0 greenlet-3.2.3 h11-0.16.0 httpcore-1.0.9 httplib2-0.22.0 httpx-0.28.1 idna-3.10 jiter-0.10.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.3.25 langchain-core-0.3.65 langchain-text-splitters-0.3.8 langsmith-0.3.45 oauthlib-3.2.2 openai-1.86.0 orjson-3.10.18 packaging-24.2 proto-plus-1.26.1 protobuf-6.31.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 pydantic-2.11.5 pydantic-core-2.33.2 pyparsing-3.2.3 requests-2.32.4 requests-oauthlib-2.0.0 requests-toolbelt-1.0.0 rsa-4.9.1 sniffio-1.3.1 tenacity-9.1.2 tqdm-4.67.1 typing-extensions-4.14.0 typing-inspection-0.4.1 uritemplate-4.2.0 urllib3-2.4.0 zstandard-0.23.0

# %%
# !pip install openai google-api-python-client google-auth-httplib2 google-auth-oauthlib langchain pytz
# Out:
# Requirement already satisfied: openai in c:\users\user\admin agent\.venv\lib\site-packages (1.86.0)
# Requirement already satisfied: google-api-python-client in c:\users\user\admin agent\.venv\lib\site-packages (2.172.0)
# Requirement already satisfied: google-auth-httplib2 in c:\users\user\admin agent\.venv\lib\site-packages (0.2.0)
# Requirement already satisfied: google-auth-oauthlib in c:\users\user\admin agent\.venv\lib\site-packages (1.2.2)
# Requirement already satisfied: langchain in c:\users\user\admin agent\.venv\lib\site-packages (0.3.25)
# Requirement already satisfied: pytz in c:\users\user\admin agent\.venv\lib\site-packages (2025.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\user\admin agent\.venv\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\user\admin agent\.venv\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\admin agent\.venv\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\user\admin agent\.venv\lib\site-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\user\admin agent\.venv\lib\site-packages (from openai) (2.11.5)
# Requirement already satisfied: sniffio in c:\users\user\admin agent\.venv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\user\admin agent\.venv\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\user\admin agent\.venv\lib\site-packages (from openai) (4.14.0)
# Requirement already satisfied: idna>=2.8 in c:\users\user\admin agent\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\user\admin agent\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\user\admin agent\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\user\admin agent\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\admin agent\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\user\admin agent\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\user\admin agent\.venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\user\admin agent\.venv\lib\site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in c:\users\user\admin agent\.venv\lib\site-packages (from google-api-python-client) (2.40.3)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\user\admin agent\.venv\lib\site-packages (from google-api-python-client) (2.25.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\user\admin agent\.venv\lib\site-packages (from google-api-python-client) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\user\admin agent\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\user\admin agent\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (6.31.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\user\admin agent\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\user\admin agent\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\user\admin agent\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\admin agent\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\user\admin agent\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (4.9.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\user\admin agent\.venv\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\admin agent\.venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\admin agent\.venv\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.4.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\user\admin agent\.venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\user\admin agent\.venv\lib\site-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in c:\users\user\admin agent\.venv\lib\site-packages (from langchain) (0.3.65)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\user\admin agent\.venv\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\user\admin agent\.venv\lib\site-packages (from langchain) (0.3.45)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\user\admin agent\.venv\lib\site-packages (from langchain) (2.0.41)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\user\admin agent\.venv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\user\admin agent\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\user\admin agent\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\user\admin agent\.venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (24.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\user\admin agent\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\user\admin agent\.venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\user\admin agent\.venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\user\admin agent\.venv\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: greenlet>=1 in c:\users\user\admin agent\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user\admin agent\.venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: colorama in c:\users\user\admin agent\.venv\lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from google.auth.transport.requests import Request
import pickle
import os

# If modifying these SCOPES, delete the file token.pkl.
SCOPES = ['https://www.googleapis.com/auth/calendar']

def authenticate_google():
    creds = None
    # The file token.pkl stores the user's access and refresh tokens.
    if os.path.exists('token.pkl'):
        with open('token.pkl', 'rb') as token:
            creds = pickle.load(token)
    # If there are no (valid) credentials, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.pkl', 'wb') as token:
            pickle.dump(creds, token)
    return creds

# Authenticate and get credentials
creds = authenticate_google()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=885913184552-86iog4pkulojgr4r46vjse61ukaa3ds8.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A53712%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcalendar&state=Y44n2CLTCXiFjVTeQPcBKu3JP89nni&access_type=offline

# %%
from datetime import datetime, timedelta
import pytz
from dateutil.parser import parse
from googleapiclient.discovery import build

def list_today_calendar_events(creds):
    service = build('calendar', 'v3', credentials=creds)

    local_tz = pytz.timezone('Africa/Lagos')
    now = datetime.now(local_tz)
    start_of_day = now.replace(hour=0, minute=0, second=0, microsecond=0)
    end_of_day = now.replace(hour=23, minute=59, second=59, microsecond=0)

    time_min = start_of_day.isoformat()
    time_max = end_of_day.isoformat()

    events_result = service.events().list(
        calendarId='primary',
        timeMin=time_min,
        timeMax=time_max,
        singleEvents=True,
        orderBy='startTime'
    ).execute()

    events = events_result.get('items', [])

    if not events:
        print('🌸 No events scheduled for today.')
        return

    print('📅 Today\'s Events:')
    print('-------------------')

    previous_event_end = None

    for event in events:
        summary = event.get('summary', 'No Title')
        
        if 'dateTime' in event['start']:
            start_dt = parse(event['start']['dateTime'])
            end_dt = parse(event['end']['dateTime'])
            print(f"🕒 {start_dt.strftime('%H:%M')} - {end_dt.strftime('%H:%M')} | {summary}")
        else:
            print(f"📅 All Day | {summary}")
            continue

        # Meeting Preparation Reminder
        keywords = ['call', 'meeting', 'sync', 'catch-up']
        if any(keyword.lower() in summary.lower() for keyword in keywords):
            print("   ➡️ Prep needed: Fetch notes, LinkedIn bios, previous threads.")

        # Overlap detection
        if previous_event_end and start_dt < previous_event_end:
            print("   ⚠️ Conflict detected with previous event! Consider rescheduling.")

        previous_event_end = end_dt

    print('-------------------')

# Call the function
list_today_calendar_events(creds)
# Out:
# 🌸 No events scheduled for today.

# %%
def calendar_agent_menu(creds):
    while True:
        print("\n📅 Calendar Agent Menu:")
        print("1. View Today's Events")
        print("2. Create New Event")
        print("3. Reschedule Event")
        print("4. Delete Event")
        print("5. Exit")
        choice = "1"

        if choice == '1':
            list_today_calendar_events(creds)

        elif choice == '2':
            # Create event
            summary = input("Enter event summary/title: ")
            description = input("Enter event description (optional): ")
            attendees = input("Enter attendees' emails separated by comma (optional): ").split(',')

            date_input = input("Enter date (YYYY-MM-DD): ")
            start_time_input = input("Enter start time (HH:MM, 24hr format): ")
            end_time_input = input("Enter end time (HH:MM, 24hr format): ")

            local_tz = pytz.timezone('Africa/Lagos')
            start_dt = local_tz.localize(datetime.strptime(f"{date_input} {start_time_input}", "%Y-%m-%d %H:%M"))
            end_dt = local_tz.localize(datetime.strptime(f"{date_input} {end_time_input}", "%Y-%m-%d %H:%M"))

            create_calendar_event(creds, summary, start_dt, end_dt, description, [email.strip() for email in attendees if email])

        elif choice == '3':
            # Reschedule event
            event_id = input("Enter the Event ID to reschedule: ")

            date_input = input("Enter new date (YYYY-MM-DD): ")
            start_time_input = input("Enter new start time (HH:MM, 24hr format): ")
            end_time_input = input("Enter new end time (HH:MM, 24hr format): ")

            local_tz = pytz.timezone('Africa/Lagos')
            new_start_dt = local_tz.localize(datetime.strptime(f"{date_input} {start_time_input}", "%Y-%m-%d %H:%M"))
            new_end_dt = local_tz.localize(datetime.strptime(f"{date_input} {end_time_input}", "%Y-%m-%d %H:%M"))

            reschedule_calendar_event(creds, event_id, new_start_dt, new_end_dt)

        elif choice == '4':
            # Delete event
            event_id = input("Enter the Event ID to delete: ")
            delete_calendar_event(creds, event_id)

        elif choice == '5':
            print("👋 Exiting Calendar Agent. Have a wonderful day!")
            break

        else:
            print("⚠️ Invalid choice. Please try again.")

# %%
calendar_agent_menu(creds)
# Out:
# 📅 Calendar Agent Menu:
# 1. View Today's Events
# 2. Create New Event
# 3. Reschedule Event
# 4. Delete Event
# 5. Exit
# 👋 Exiting Calendar Agent. Have a wonderful day!
